# %%
prompt = """
You are a friendly AI assistant, ForgeMind, who turns descriptions of CAD operations for AutoDesk Fusion into python scripts which perform the described operation.
"""

# %%
def read_file(file_path: str) -> str:
    """
    Reads the content of a file and returns it as a string.
    
    Parameters:
    file_path (str): The path to the file to be read.
    
    Returns:
    str: The content of the file.
    """
    content = ''
    with open(file_path, 'r') as file:
        content = file.read('text_to_fusion/unprocessed/${file_path}')
    return content

# %%
dataset = [
    {
        "user": "Create a cylinder with a radius of 5 and a height of 20",
        "response": read_file("cylinder.py")
    },
    {
        "user": "Create a 5x5x5 cube",
        "response": read_file("cube.py")
    },
    {
        "user": "Draw me an L shape with length 4 on both sides and a thickness of 2",
        "response": read_file("l_shape.py")
    },
    {
        "user": "Make a hollow cylinder with an outer radius of 2, inner radius of 1, and a height of 4",
        "response": read_file("hollow_cylinder.py")
    },
    {
        "user": "Design a rectangular prism with width 10, height 40, and depth 12",
        "response": read_file("rectangular_prism.py")
    },
    {
        "user": "Create a stop sign with side length 100 and depth 20",
        "response": read_file("stop_sign.py")
    },
    {
        "user": "Create a 5x5x5 cube with radius 3 circular hole through the middle",
        "response": read_file("cube_with_hole.py")
    },
    {
        "user": "Delete all bodies and sketches",
        "response": read_file("delete_all.py")
    },
    {
        "user": "Create a 10x10 square on the XZ plane",
        "response": read_file("square.py")
    },
    {
        "user": "Extrude my sketch by 2 units",
        "response": read_file("extrude.py")
    },
    {
        "user": "create 2 circles on the xz plane along the x axis that are 2 cm away from the origin with a radius of 3mm",
        "response": read_file("circles.py")
    },
    {
        "user": "fillet the edges of this body with a radius of 3mm",
        "response": read_file("fillet.py")
    },
    {
        "user": "draw a disk with a radius of 2cm centered at the origin along the xz plane, give it a thickness of 0.5 cm",
        "response": read_file("disk.py")
    },
    {
        "user": "create a circle with a diameter of 7.5cm on the xz plane, centered at the origin and give it a thickness of 0.5cm",
        "response": read_file("disk_diameter.py")
    },
    {
        "user": "create a hollow cylinder with an outer diameter of 7.5cm and a wall thickness of 0.5cm on the xz plane, and extrude 12cm along the z axis",
        "response": read_file("hollow_cylinder_2.py")
    },
    {
        "user": "create a circle about the origin on the xz plane with a diameter of 6.5cm and extrude 0.5cm along the z axis. Join it to my current body",
        "response": read_file("join_cylinder.py")
    },
    {
        "user": "fillet all my edges with a radius of 1mm",
        "response": read_file("fillet_all.py")
    },
    {
        "user": "change the radius of all my fillets to 2mm",
        "response": read_file("change_fillet_radius.py")
    },
    {
        "user": "remove all fillets",
        "response": read_file("remove_all_fillets.py")
    },
    {
        "user": "Write 3D text that says 'YC'",
        "response": read_file("write_text.py")
    }
]
